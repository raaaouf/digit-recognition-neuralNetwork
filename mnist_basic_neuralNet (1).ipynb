# %% [markdown]
# # Handwritten Digit Recognition

# %% [markdown]
# ## Step 1: Define the Problem & Collect Data

# %% [markdown]
# **Q**: What are you trying to predict?<br/>
# **A**: Classify images of handwritten digits into their 10 categories (0 to 9).
#
#
# **Q**: What will your input data be?<br/>
# **A**: Grayscale images of handwritten digits (28x28 pixels).
#
#
# **Q**: What type of problem are you facing?<br/>
# **A**: Binary classification
#
#
# **Q**: What is the size of your dataset?<br/>
# **A**: There are 60,000 training samples and 10,000 test samples.

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
import matplotlib.pyplot as plt

grid_size = 6
f, axarr = plt.subplots(grid_size, grid_size)
for i in range(grid_size):
    for j in range(grid_size):
        axarr[i, j].imshow(train_images[i * grid_size + j])

# %% [markdown]
# ## Step 2: Pick Success Metrics

# %% [markdown]
# **Q**: What is your metric for success?<br/>
# **A**: Accuracy
#
# **Q**: What value of your success metric are you aiming for?<br/>
# **A**: 90%

# %% [markdown]
# ## Step 3: Pick an Evaluation Protocol and Prepare Your Data

# %% [markdown]
# **Q**: What approach are going to follow for validation?<br/>
# **A**: Hold out validation.
#
# **Q**: Does your data require normalization or scaling?<br/>
# **A**: Yes, pixel values are in the range \[0,255\] and need to be scaled down to \[0,1\].
#
# **Q**: What is the training/validation/test split?<br/>
# **A**: 75-25 training/validation split.
# Training:   45,000 samples
# Validation: 15,000 samples
# Test:       10,000 samples
#
# **Q**: Can/should the data be randomized before splitting?<br/>
# **A**: Not required. It's already randomized.
#
# **Q**: Can you come up with new features using existing ones to make the problem easier?<br/>
# **A**: Not required.

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

from keras.utils import to_categorical

partial_train_images = train_images[:45000]
partial_train_labels = train_labels[:45000]

validation_images = train_images[45000:]
validation_labels = train_labels[45000:]

partial_train_labels = to_categorical(partial_train_labels)
validation_labels = to_categorical(validation_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# ## Step 4: Develop the First Model

# %% [markdown]
# The first goal is to develop a model that is capable of beating a dumb baseline. There are 3 key choices to be made:
# 1. Last-layer activation function
# 2. Loss function
# 3. Optimization configuration (generally, `rmsprop` is good enough).
#
# <table>
#     <tr>
#         <th>Problem Type</th>
#         <th>Last-layer Activation</th>
#         <th>Loss Function</th>
#     </tr>
#     <tr>
#         <td>Binary Classification</td>
#         <td>`sigmoid`</td>
#         <td>`binary_crossentropy`</td>
#     </tr>
#     <tr>
#         <td>Multi-class, single-label classification</td>
#         <td>`softmax`</td>
#         <td>`categorical_crossentropy`</td>
#     </tr>
#     <tr>
#         <td>Multi-class, multi-label classification</td>
#         <td>`sigmoid`</td>
#         <td>`binary_crossentropy`</td>
#     </tr>
#     <tr>
#         <td>Regression to arbitrary values</td>
#         <td>None</td>
#         <td>`mse`</td>
#     </tr>
#     <tr>
#         <td>Regression to values in `[0,1]`</td>
#         <td>`sigmoid`</td>
#         <td>`mse` or `binary_crossentropy`</td>
#     </tr>
# </table>

# %%
from keras import models
from keras import layers

network = models.Sequential()
network.add(layers.Dense(32, activation='relu', input_shape=(28 * 28, )))
network.add(layers.Dense(10, activation='softmax'))

network.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = network.fit(
    partial_train_images, 
    partial_train_labels, 
    epochs=12, 
    batch_size=128, 
    validation_data=(validation_images, validation_labels))
# Out:
# Epoch 1/12
# 352/352 [==============================] - 2s 5ms/step - loss: 0.5291 - accuracy: 0.8647 - val_loss: 0.3055 - val_accuracy: 0.9149
# Epoch 2/12
# 352/352 [==============================] - 1s 4ms/step - loss: 0.2853 - accuracy: 0.9197 - val_loss: 0.2558 - val_accuracy: 0.9281
# Epoch 3/12
# 352/352 [==============================] - 2s 4ms/step - loss: 0.2396 - accuracy: 0.9318 - val_loss: 0.2279 - val_accuracy: 0.9348
# Epoch 4/12
# 352/352 [==============================] - 1s 3ms/step - loss: 0.2083 - accuracy: 0.9400 - val_loss: 0.2104 - val_accuracy: 0.9395
# Epoch 5/12
# 352/352 [==============================] - 1s 2ms/step - loss: 0.1859 - accuracy: 0.9462 - val_loss: 0.1936 - val_accuracy: 0.9455
# Epoch 6/12
# 352/352 [==============================] - 1s 3ms/step - loss: 0.1679 - accuracy: 0.9510 - val_loss: 0.1860 - val_accuracy: 0.9480
# Epoch 7/12
# 352/352 [==============================] - 1s 3ms/step - loss: 0.1539 - accuracy: 0.9546 - val_loss: 0.1766 - val_accuracy: 0.9499
# Epoch 8/12
# 352/352 [==============================] - 1s 3ms/step - loss: 0.1417 - accuracy: 0.9586 - val_loss: 0.1751 - val_accuracy: 0.9521
# Epoch 9/12
# 352/352 [==============================] - 1s 2ms/step - loss: 0.1330 - accuracy: 0.9614 - val_loss: 0.1675 - val_accuracy: 0.9509
# Epoch 10/12
# 352/352 [==============================] - 1s 3ms/step - loss: 0.1244 - accuracy: 0.9639 - val_loss: 0.1637 - val_accuracy: 0.9529
# Epoch 11/12
# 352/352 [==============================] - 1s 3ms/step - loss: 0.1169 - accuracy: 0.9670 - val_loss: 0.1596 - val_accuracy: 0.9541
# Epoch 12/12
# 352/352 [==============================] - 1s 3ms/step - loss: 0.1114 - accuracy: 0.9679 - val_loss: 0.1551 - val_accuracy: 0.9557

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.margins(0.05)

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.margins(0.05)

plt.show()

# %% [markdown]
# ## Step 5: Develop a Model That Overfits
#
# The final objective is to find the balance between:
# * Optimization and generalization
# * Under-fitting and over-fitting
# * Under-capacity and over-capacity
#
# To figure out how big a model is required, you must develop a model that overfits, using one or more of the following approaches:
# * Add layers
# * Makes layers bigger
# * Train for more epochs
#
# Plot the values of the loss function and the success metrics on the training and validation datasets to identify where the model starts over-fitting.

# %%
from keras import regularizers

network2 = models.Sequential()
network2.add(layers.Dense(784, activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(28 * 28, )))
network2.add(layers.Dense(784, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
network2.add(layers.Dense(784, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
network2.add(layers.Dense(10, activation='softmax'))

network2.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = network2.fit(
    partial_train_images, 
    partial_train_labels, 
    epochs=30, 
    batch_size=128, 
    validation_data=(validation_images, validation_labels))
# Out:
# Epoch 1/30
# 352/352 [==============================] - 18s 51ms/step - loss: 0.9733 - accuracy: 0.9034 - val_loss: 0.4078 - val_accuracy: 0.9536
# Epoch 2/30
# 352/352 [==============================] - 18s 50ms/step - loss: 0.3441 - accuracy: 0.9547 - val_loss: 0.2903 - val_accuracy: 0.9605
# Epoch 3/30
# 352/352 [==============================] - 17s 50ms/step - loss: 0.2521 - accuracy: 0.9644 - val_loss: 0.3290 - val_accuracy: 0.9373
# Epoch 4/30
# 352/352 [==============================] - 17s 50ms/step - loss: 0.2115 - accuracy: 0.9694 - val_loss: 0.2336 - val_accuracy: 0.9597
# Epoch 5/30
# 352/352 [==============================] - 17s 50ms/step - loss: 0.1901 - accuracy: 0.9725 - val_loss: 0.2574 - val_accuracy: 0.9515
# Epoch 6/30
# 352/352 [==============================] - 19s 53ms/step - loss: 0.1745 - accuracy: 0.9735 - val_loss: 0.1960 - val_accuracy: 0.9670
# Epoch 7/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1621 - accuracy: 0.9759 - val_loss: 0.1901 - val_accuracy: 0.9674
# Epoch 8/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1524 - accuracy: 0.9778 - val_loss: 0.1753 - val_accuracy: 0.9703
# Epoch 9/30
# 352/352 [==============================] - 17s 50ms/step - loss: 0.1453 - accuracy: 0.9784 - val_loss: 0.2213 - val_accuracy: 0.9561
# Epoch 10/30
# 352/352 [==============================] - 20s 56ms/step - loss: 0.1371 - accuracy: 0.9798 - val_loss: 0.1889 - val_accuracy: 0.9650
# Epoch 11/30
# 352/352 [==============================] - 19s 53ms/step - loss: 0.1345 - accuracy: 0.9810 - val_loss: 0.1801 - val_accuracy: 0.9663
# Epoch 12/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1279 - accuracy: 0.9820 - val_loss: 0.2070 - val_accuracy: 0.9579
# Epoch 13/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1261 - accuracy: 0.9820 - val_loss: 0.2405 - val_accuracy: 0.9492
# Epoch 14/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1239 - accuracy: 0.9818 - val_loss: 0.2498 - val_accuracy: 0.9439
# Epoch 15/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1213 - accuracy: 0.9828 - val_loss: 0.2089 - val_accuracy: 0.9580
# Epoch 16/30
# 352/352 [==============================] - 17s 50ms/step - loss: 0.1186 - accuracy: 0.9835 - val_loss: 0.1549 - val_accuracy: 0.9731
# Epoch 17/30
# 352/352 [==============================] - 17s 50ms/step - loss: 0.1157 - accuracy: 0.9830 - val_loss: 0.1652 - val_accuracy: 0.9695
# Epoch 18/30
# 352/352 [==============================] - 18s 50ms/step - loss: 0.1162 - accuracy: 0.9832 - val_loss: 0.1577 - val_accuracy: 0.9709
# Epoch 19/30
# 352/352 [==============================] - 17s 50ms/step - loss: 0.1123 - accuracy: 0.9844 - val_loss: 0.1910 - val_accuracy: 0.9619
# Epoch 20/30
# 352/352 [==============================] - 17s 50ms/step - loss: 0.1120 - accuracy: 0.9838 - val_loss: 0.1599 - val_accuracy: 0.9711
# Epoch 21/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1086 - accuracy: 0.9841 - val_loss: 0.1820 - val_accuracy: 0.9650
# Epoch 22/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1084 - accuracy: 0.9848 - val_loss: 0.1529 - val_accuracy: 0.9730
# Epoch 23/30
# 352/352 [==============================] - 18s 50ms/step - loss: 0.1074 - accuracy: 0.9849 - val_loss: 0.1684 - val_accuracy: 0.9681
# Epoch 24/30
# 352/352 [==============================] - 18s 51ms/step - loss: 0.1082 - accuracy: 0.9842 - val_loss: 0.1813 - val_accuracy: 0.9652
# Epoch 25/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1071 - accuracy: 0.9848 - val_loss: 0.1460 - val_accuracy: 0.9745
# Epoch 26/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1058 - accuracy: 0.9853 - val_loss: 0.1534 - val_accuracy: 0.9727
# Epoch 27/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1057 - accuracy: 0.9846 - val_loss: 0.1685 - val_accuracy: 0.9680
# Epoch 28/30
# 352/352 [==============================] - 18s 52ms/step - loss: 0.1035 - accuracy: 0.9853 - val_loss: 0.1521 - val_accuracy: 0.9725
# Epoch 29/30
# 352/352 [==============================] - 20s 56ms/step - loss: 0.1024 - accuracy: 0.9852 - val_loss: 0.1590 - val_accuracy: 0.9715
# Epoch 30/30
# 352/352 [==============================] - 17s 49ms/step - loss: 0.1025 - accuracy: 0.9852 - val_loss: 0.1510 - val_accuracy: 0.9726

# %%
acc = history.history['accuracy']
loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs[0:], acc[0:], 'bo', label='Training acc')
plt.plot(epochs[0:], val_acc[0:], 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.margins(0.05)

plt.figure()

plt.plot(epochs[0:], loss[0:], 'bo', label='Training loss')
plt.plot(epochs[0:], val_loss[0:], 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.margins(0.05)

plt.show()

# %% [markdown]
# ## Step 6: Regularize the Model and Tune the Hyperparameters

# %% [markdown]
# This part will take the most time. You will repeatedly modify your model, train it, evaluate on your validation data, modify it again... until your model is as good as it can get.
#
# Following are some approaches for improving the model:
# * Add dropout
# * Try different architectures, add or remove layers
# * Add L1 / L2 regularization
# * Try different hyperparameters to find the optimal cofiguration, e.g.:
#     * No. of units per layer
#     * Learning rate of the optimizer
# * Iterate on feature engineering: add new features, remove features that do not seem informative
#
# Be mindful of the following: every time you are using feedback from your validation process in order to tune your model, you are leaking information about your validation process into your model. This can cause overfitting on the validation data.
#
# Once you have developed a seemingly good enough model configuration, you can train your final production model on all data available (training and validation) and evaluate it one last time on the test set. Finally, you can save your model to disk, so that it can be reused later.

# %%
from keras import regularizers

network2 = models.Sequential()
network2.add(layers.Dense(784, activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(28 * 28, )))
network2.add(layers.Dense(784, activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(28 * 28, )))
network2.add(layers.Dense(784, activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(28 * 28, )))
network2.add(layers.Dense(10, activation='softmax'))

network2.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = network2.fit(
    train_images, 
    to_categorical(train_labels), 
    epochs=14, 
    batch_size=128)
# Out:
# Epoch 1/14
# 469/469 [==============================] - 23s 49ms/step - loss: 0.8277 - accuracy: 0.9151
# Epoch 2/14
# 469/469 [==============================] - 21s 45ms/step - loss: 0.2880 - accuracy: 0.9602
# Epoch 3/14
# 469/469 [==============================] - 21s 45ms/step - loss: 0.2207 - accuracy: 0.9675
# Epoch 4/14
# 469/469 [==============================] - 21s 45ms/step - loss: 0.1900 - accuracy: 0.9711
# Epoch 5/14
# 469/469 [==============================] - 22s 46ms/step - loss: 0.1722 - accuracy: 0.9730
# Epoch 6/14
# 469/469 [==============================] - 24s 51ms/step - loss: 0.1605 - accuracy: 0.9755
# Epoch 7/14
# 469/469 [==============================] - 21s 44ms/step - loss: 0.1514 - accuracy: 0.9770
# Epoch 8/14
# 469/469 [==============================] - 21s 44ms/step - loss: 0.1463 - accuracy: 0.9774
# Epoch 9/14
# 469/469 [==============================] - 21s 45ms/step - loss: 0.1378 - accuracy: 0.9787
# Epoch 10/14
# 469/469 [==============================] - 21s 45ms/step - loss: 0.1339 - accuracy: 0.9786
# Epoch 11/14
# 469/469 [==============================] - 21s 45ms/step - loss: 0.1299 - accuracy: 0.9796
# Epoch 12/14
# 469/469 [==============================] - 21s 45ms/step - loss: 0.1275 - accuracy: 0.9801
# Epoch 13/14
# 469/469 [==============================] - 21s 45ms/step - loss: 0.1249 - accuracy: 0.9805
# Epoch 14/14
# 469/469 [==============================] - 21s 45ms/step - loss: 0.1215 - accuracy: 0.9816

# %%
test_loss, test_acc = network2.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1513 - accuracy: 0.9737

# %%
print('Test loss:', test_loss)
print('Test acc:', test_acc)
# network2.save('../models/00_mnist_basic.h5')
# Out:
# Test loss: 0.1513310819864273
# Test acc: 0.9736999869346619
